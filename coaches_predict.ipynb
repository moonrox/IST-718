# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
filename = 'outfile.csv'
data = pd.read_csv(filename, sep=',', comment='#', error_bad_lines=False)
data = data.dropna()
data.head()

#Print the Mean of the Total Pay Column
# Out:
#    record      ID                 School Conference              Coach  \
# 1      85  200800                  Akron        MAC       Terry Bowden
# 2       2  100751                Alabama        SEC         Nick Saban
# 3       1  100663  Alabama at Birmingham      C-USA         Bill Clark
# 4      78  197869      Appalachian State   Sun Belt  Scott Satterfield
# 5       7  104151                Arizona     Pac-12       Kevin Sumlin
#
#    SchoolPay  TotalPay      Bonus  BonusPaid  AssistantPay  ...  OPEID6  \
# 1   411000.0    412500   225000.0    50000.0             0  ...      66
# 2  8307000.0   8307000  1100000.0   500000.0             0  ...      65
# 3   900000.0    900000   950000.0   165471.0             0  ...      75
# 4   712500.0    712500   295000.0   145000.0             0  ...      74
# 5  1600000.0   2000000  2025000.0        0.0             0  ...      74
#
#   COUNT_ED AGEGE24  PCT_WHITE  PCT_BLACK  PCT_ASIAN  PCT_HISPANIC     PCT_BA  \
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(data['TotalPay'],data['Bonus'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(data['TotalPay'],data['GSR'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(data['TotalPay'],data['FGR'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(data['TotalPay'],data['PCT_BORN_US'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(data['TotalPay'],data['Conference'])

# %%
from sklearn.model_selection import train_test_split
X = data[['Bonus', 'SchoolPay', 'StadiumCapacity']]
y = data['TotalPay']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
X_train
y_test
# Out:
# 113    5500000
# 102    4200000
# 45     5000000
# 133    3617500
# 125    3787917
# 63     2600000
# 57      390000
# 67     4390417
# 49     1701109
# 43     3060018
# 3       900000
# 51      440000
# 130    1831580
# 56      850000
# 42      569000
# 2      8307000
# 89     5000000
# 60      762570
# 11      825000
# 62      500000
# 88     4800000
# 110    3846000
# 47     4700000
# 75      500000
# 30     1800000
# 52     4013600
# Name: TotalPay, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
clf.predict(X_train)
# Out:
# array([1701633.62058506, 1654278.52716397, 3830316.32112714,
#        1604670.20142598,  664150.07504111, 1113124.28826545,
#        2801509.58475869,  707920.43606798, 2138421.28815551,
#        3340583.86140075, 1506583.81888461,  647056.86672075,
#        3031577.09722474,  587618.03755903, 3041743.4945618 ,
#        4018799.10515428,  518561.81177645, 1022458.63687533,
#        2614863.72180923,  909883.15715864, 3875037.02296927,
#         578250.76394645, 1849738.48655741,  610249.84047809,
#        2084233.81681333, 5017057.39189154, 4054622.07249622,
#        4009443.95536784, 1430472.39025112, 3585056.58392468,
#        5009239.18223648, 2632322.46356365, 2547761.86236389,
#         698876.61678225,  530061.46109167,  407937.6177583 ,
#        2359633.90182818, 1655813.69293448, 1657468.65780613,
#        3517729.23961448, 5491737.28849879, 7625687.27148903,
#        2082578.85194168, 3507906.31544613,  457293.77701845,
# ...

# %%
clf.score(X_test, y_test)
# Out:
# 0.9998053610344763

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = data[['GSR', 'StadiumCapacity', 'FGR','Bonus','PCT_BORN_US','PCT_BLACK', 'PCT_WHITE']]
y = data['TotalPay']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
clf = LinearRegression()
clf.fit(X_train, y_train)
clf.predict(X_train)
clf.score(X_test, y_test)
# Out:
# 0.4343905405455706
